# %% [markdown]
# <a href="https://colab.research.google.com/github/IA-MachineLearning-Relatorios/Classification-Trees/blob/main/ClassificationTrees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Splitting Data into Training and Testing Sets
#
# Before training a machine learning model, it's crucial to split your dataset into two subsets: a training set and a testing set.
#
# *   **Training Set**: Used to train the model.
# *   **Testing Set**: Used to evaluate the model's performance on unseen data.
#
# This helps in assessing how well the model generalizes to new data and prevents overfitting.

# %%
import numpy as np
from sklearn.datasets import make_classification

# Generate some sample data for demonstration
X, y = make_classification(n_samples=100, n_features=4, n_informative=2, n_redundant=0, random_state=42)

print("Shape of X (features):"), X.shape
print("Shape of y (target):"), y.shape

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
# test_size=0.30 means 30% of the data will be used for testing
# random_state ensures reproducibility of the split
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.30, random_state=42)

print(f"Shape of X_treino: {X_treino.shape}")
print(f"Shape of y_treino: {y_treino.shape}")
print(f"Shape of X_teste: {X_teste.shape}")
print(f"Shape of y_teste: {y_teste.shape}")

# %% [markdown]
# codigo abaixo feito para entender as melhroes praticas de classification trees

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

modelo = DecisionTreeClassifier(criterion='entropy', max_depth=3)
modelo.fit(X_treino, y_treino)

modelo.predict(X_teste)

y_pred = modelo.predict(X_teste)
acuracia = accuracy_score(y_teste, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1365/619198464.py in <cell line: 0>()
#       3
#       4 modelo = DecisionTreeClassifier(criterion='entropy', max_depth=3)
# ----> 5 modelo.fit(X_treino, y_treino)
#       6
#       7 modelo.predict(X_teste)
#
# NameError: name 'X_treino' is not defined
